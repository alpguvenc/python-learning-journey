# %%
print("Merhaba Dünya!")

x = 1
y = 10

print(x)
print(y)
print(x*y)
print(x+y)
print(x/y)
print(x-y)
print(x%y)
print(x**y)

x = int(input("Lütfen yaşınızı giriniz: "))
y = str(input("Lütfen adınızı giriniz: "))

print("Adınız: ", y)
print("Yaşınız: ", x)
print("Girmiş olduğunuz veriler şunlar: ")
print(x, "=", type(x))
print(y, "=", type(y))

print("Doğum Yılınız: ", 2025-x)

sayi1 = int (input("Lütfen karesi alınacak sayı giriniz: "))

print(sayi1, "sayısının karesi: ", sayi1**2)

sayi2 = int (input("Lütfen birinci sayıyı giriniz: "))
sayi3 = int (input("Lütfen ikinci sayıyı giriniz: "))

print(sayi2, "ile", sayi3, "çarpımı", sayi2*sayi3, "eder.")
print(sayi2, "ile", sayi3, "farkı", sayi2-sayi3, "eder.")
print(sayi2, "bölü", sayi3, ",", sayi2/sayi3, "eder.")
print(sayi2, "ile", sayi3, "toplamı", sayi2+sayi3, "eder.")
print(sayi2, "bölü", sayi3, "işleminin kalanı", sayi2%sayi3, "eder.")
# Out:
# Merhaba Dünya!
# 1
# 10
# 10
# 11
# 0.1
# -9
# 1
# 1
# Lütfen yaşınızı giriniz: 26
# Lütfen adınızı giriniz: Alp
# Adınız:  Alp
# Yaşınız:  26
# Girmiş olduğunuz veriler şunlar:
# 26 = <class 'int'>
# Alp = <class 'str'>
# Doğum Yılınız:  1999
# Lütfen karesi alınacak sayı giriniz: 45
# 45 sayısının karesi:  2025
# Lütfen birinci sayıyı giriniz: 23
# Lütfen ikinci sayıyı giriniz: 2
# 23 ile 2 çarpımı 46 eder.
# 23 ile 2 farkı 21 eder.
# 23 bölü 2 , 11.5 eder.
# 23 ile 2 toplamı 25 eder.
# 23 bölü 2 işleminin kalanı 1 eder.

# %%
x = int(13)
y = str("Alp")
z = float(3.14)
q = bool(True)

print(x)
print(y)
print(z)
print(q)

x = int(input("Yaşınızı girin: "))
y = str(input("Adınızı girin: "))
z = float(input("Boyunuzu metre cinsinden girin: "))
q = bool(input("Yukarıdaki bilgileri onaylıyorsanız 1 yazın: "))

print(x)
print(y)
print(z)
print(q)

print(type(x))
print(type(y))
print(type(z))
print(type(q))
# Out:
# 13
# Alp
# 3.14
# True
# Yaşınızı girin: 26
# Adınızı girin: Alp
# Boyunuzu metre cinsinden girin: 1.78
# Yukarıdaki bilgileri onaylıyorsanız 1 yazın: 1
# 26
# Alp
# 1.78
# True
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
a = input("Adınız nedir? \n")
b = int (input("Yaşınız kaç? \n"))

print("Merhaba", a)
print("10 yıl sonra", b+10, "yaşında olacaksınız.")
# Out:
# Adınız nedir?
# Alp
# Yaşınız kaç?
# 26
# Merhaba Alp
# 10 yıl sonra 36 yaşında olacaksınız.

# %%
ad = input("Ad Soyad: ")
yas = int(input("Yaş: "))
meslek = input("Meslek: ")
en_sevdigi = input("En sevdiğin şey: ")
hakkinda = input("Kendinden bahset: ")

print("----- INSTAGRAM BIO -----")
print(f"{ad} | {yas} | {meslek}")
print(f"{en_sevdigi} tutkunu")
print(hakkinda)
# Out:
# Ad Soyad: Alp
# Yaş: 26
# Meslek: Pazarlama
# En sevdiğin şey: Sinema
# Kendinden bahset: Yeni şeyler öğrenmeyi severim
# ----- INSTAGRAM BIO -----
# Alp | 26 | Pazarlama
# Sinema tutkunu
# Yeni şeyler öğrenmeyi severim
